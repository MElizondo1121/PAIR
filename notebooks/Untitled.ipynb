# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_zip = pd.read_csv('../data/SDOH/SDOH_2020_ZIPCODE_1_0.csv').drop('YEAR', axis=1)
df_zip
# Out:
#        STATEFIPS  ZIPCODE     ZCTA       STATE REGION  TERRITORY  POINT_ZIP  \
# 0             15    96759      NaN      Hawaii    NaN          0          1
# 1              2    99675      NaN      Alaska    NaN          0          1
# 2             41    97010      NaN      Oregon    NaN          0          0
# 3              6    93928      NaN  California    NaN          0          1
# 4              6    95836      NaN  California    NaN          0          0
# ...          ...      ...      ...         ...    ...        ...        ...
# 41046          2    99923  99923.0      Alaska   West          0          0
# 41047          2    99925  99925.0      Alaska   West          0          0
# 41048          2    99926  99926.0      Alaska   West          0          0
# 41049          2    99927  99927.0      Alaska   West          0          0
# 41050          2    99929  99929.0      Alaska   West          0          0
#
# ...

# %%
df_zip.columns.tolist()
# Out:
# ['STATEFIPS',
#  'ZIPCODE',
#  'ZCTA',
#  'STATE',
#  'REGION',
#  'TERRITORY',
#  'POINT_ZIP',
#  'ACS_TOT_POP_WT_ZC',
#  'ACS_TOT_POP_US_ABOVE1_ZC',
#  'ACS_TOT_POP_ABOVE5_ZC',
#  'ACS_TOT_POP_ABOVE15_ZC',
#  'ACS_TOT_POP_ABOVE16_ZC',
#  'ACS_TOT_POP_16_19_ZC',
#  'ACS_TOT_POP_ABOVE25_ZC',
#  'ACS_TOT_CIVIL_POP_ABOVE18_ZC',
#  'ACS_TOT_CIVIL_VET_POP_ABOVE25_ZC',
#  'ACS_TOT_OWN_CHILD_BELOW17_ZC',
#  'ACS_TOT_WORKER_NWFH_ZC',
#  'ACS_TOT_WORKER_HH_ZC',
#  'ACS_TOT_CIVILIAN_LABOR_ZC',
#  'ACS_TOT_CIVIL_EMPLOY_POP_ZC',
#  'ACS_TOT_CIVIL_NONINST_POP_POV_ZC',
#  'ACS_TOT_CIVIL_POP_POV_ZC',
#  'ACS_TOT_POP_POV_ZC',
#  'ACS_TOT_GRANDCHILDREN_GP_ZC',
#  'ACS_TOT_HU_ZC',
#  'ACS_TOT_HH_ZC',
#  'ACS_AVG_HH_SIZE_ZC',
#  'ACS_TOT_CIVIL_NONINST_POP_ZC',
#  'ACS_TOT_CIVIL_VET_POP_ZC',
#  'ACS_PCT_CHILD_DISAB_ZC',
#  'ACS_PCT_DISABLE_ZC',
#  'ACS_PCT_NONVET_DISABLE_18_64_ZC',
#  'ACS_PCT_VET_DISABLE_18_64_ZC',
#  'ACS_PCT_FEMALE_ZC',
#  'ACS_PCT_MALE_ZC',
#  'ACS_PCT_CTZ_NATURALIZED_ZC',
# ...

# %%
df_county = pd.read_csv('../data/SDOH/SDOH_2020_COUNTY_1_0.csv').drop('YEAR', axis=1)
df_county
# Out:
#       COUNTYFIPS  STATEFIPS              STATE             COUNTY REGION  \
# 0           1001          1            Alabama     Autauga County  South
# 1           1003          1            Alabama     Baldwin County  South
# 2           1005          1            Alabama     Barbour County  South
# 3           1007          1            Alabama        Bibb County  South
# 4           1009          1            Alabama      Blount County  South
# ...          ...        ...                ...                ...    ...
# 3224       72151         72        Puerto Rico  Yabucoa Municipio    NaN
# 3225       72153         72        Puerto Rico    Yauco Municipio    NaN
# 3226       78010         78  US Virgin Islands          St. Croix    NaN
# 3227       78020         78  US Virgin Islands    St. John Island    NaN
# 3228       78030         78  US Virgin Islands  St. Thomas Island    NaN
#
#       TERRITORY  ACS_TOT_POP_WT  ACS_TOT_POP_US_ABOVE1  ACS_TOT_POP_ABOVE5  \
# ...

# %%
df = pd.read_csv('../data/SDOH/sdoh_2020_tract_1_0.csv').drop('YEAR', axis=1)
df
# Out:
#          TRACTFIPS  COUNTYFIPS  STATEFIPS              STATE  \
# 0       1001020100        1001          1            Alabama
# 1       1001020200        1001          1            Alabama
# 2       1001020300        1001          1            Alabama
# 3       1001020400        1001          1            Alabama
# 4       1001020501        1001          1            Alabama
# ...            ...         ...        ...                ...
# 85523  78030960900       78030         78  US Virgin Islands
# 85524  78030961000       78030         78  US Virgin Islands
# 85525  78030961100       78030         78  US Virgin Islands
# 85526  78030961200       78030         78  US Virgin Islands
# 85527  78030990000       78030         78  US Virgin Islands
#
#                   COUNTY REGION  TERRITORY  ACS_TOT_POP_WT  \
# 0         Autauga County  South          0          1941.0
# 1         Autauga County  South          0          1757.0
# ...

# %%
df.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('O'), dtype('float64')], dtype=object)

# %%
cats = df.select_dtypes(include='object')
cats
# Out:
#                    STATE             COUNTY REGION
# 0                Alabama     Autauga County  South
# 1                Alabama     Autauga County  South
# 2                Alabama     Autauga County  South
# 3                Alabama     Autauga County  South
# 4                Alabama     Autauga County  South
# ...                  ...                ...    ...
# 85523  US Virgin Islands  St. Thomas Island    NaN
# 85524  US Virgin Islands  St. Thomas Island    NaN
# 85525  US Virgin Islands  St. Thomas Island    NaN
# 85526  US Virgin Islands  St. Thomas Island    NaN
# 85527  US Virgin Islands  St. Thomas Island    NaN
#
# [85528 rows x 3 columns]

# %%
pd.set_option('display.max_rows', None)
unique_values_data = []

for column in df.columns:
    unique_values = df[column].nunique()
    unique_values_data.append({'Column': column, 'Unique Values Count': unique_values})
    if unique_values < 10:
        unique_values_data[-1]['Unique Values'] = df[column].unique()

unique_values_df = pd.DataFrame(unique_values_data)
unique_values_df
# Out:
#                             Column  Unique Values Count  \
# 0                        TRACTFIPS                85528
# 1                       COUNTYFIPS                 3234
# 2                        STATEFIPS                   56
# 3                            STATE                   56
# 4                           COUNTY                 1969
# 5                           REGION                    4
# 6                        TERRITORY                    2
# 7                   ACS_TOT_POP_WT                 8246
# 8            ACS_TOT_POP_US_ABOVE1                 8188
# 9               ACS_TOT_POP_ABOVE5                 7787
# 10             ACS_TOT_POP_ABOVE15                 6826
# 11             ACS_TOT_POP_ABOVE16                 6732
# 12               ACS_TOT_POP_16_19                 1474
# 13             ACS_TOT_POP_ABOVE25                 6044
# 14       ACS_TOT_CIVIL_POP_ABOVE18                 6579
# 15   ACS_TOT_CIVIL_VET_POP_ABOVE25                 1147
# ...

# %%
cats = ['TRACTFIPS', 'COUNTYFIPS', 'STATEFIPS', 'STATE', 'COUNTY', 'REGION', 'TERRITORY', 'CEN_AIAN_NH_IND']
df_encoded = pd.get_dummies(df, columns=cats, drop_first=True).drop_duplicates()
df_encoded

# %%
df_encoded = pd.read_csv('../data/SDOH/sdoh_2020_tract_1_0_encoded.csv').drop('YEAR', axis=1)
df_encoded
